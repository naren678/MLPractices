# %%
import pandas as pd
import numpy as np
import seaborn as sb
from sklearn.linear_model import LogisticRegression

# %%
# loading data 
bank_full = pd.read_csv("C:\\Users\\nthambat\\Downloads\\Data-Science-Case-Studies-And-Algorithms-master (1)\\Data-Science-Case-Studies-And-Algorithms-master\\6. Logistic regression\\bank-full.csv", delimiter=';',index_col=False)
bank_full.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
sb.countplot(x="y",data=bank_full)

# %%
#Data is Imbalance So making it balanced
from imblearn.combine import SMOTETomek
smk =SMOTETomek(random_state=42)
X_res,y_res=smk.fit_sample(x,y)

# %%
bank_full.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
x=bank_full.iloc[:,:-1]
y=bank_full.iloc[:,-1]
type(y)
# Out:
# pandas.core.series.Series

# %%
pd.
# Out:
# C:\Users\Public\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-e27528bf5834> in <module>()
# ----> 1 pd.Series(np.where(bank_full.y.values == 'yes', 1, 0))
#
# C:\Users\Public\Miniconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     251                 if not is_list_like(data):
#     252                     data = [data]
# --> 253                 index = _default_index(len(data))
#     254
#     255             # create/copy the manager
#
# TypeError: len() of unsized object

# %%
#Data is Imbalance So making it balanced
from imblearn.combine import SMOTETomek
smk =SMOTETomek(random_state=42)
X_res,y_res=smk.fit_sample(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-83a8d88bf7fa> in <module>()
#       2 from imblearn.combine import SMOTETomek
#       3 smk =SMOTETomek(random_state=42)
# ----> 4 X_res,y_res=smk.fit_sample(x,y)
#
# ~\AppData\Roaming\Python\Python36\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
# ---> 77         X, y, binarize_y = self._check_X_y(X, y)
#      78
#      79         self.sampling_strategy_ = check_sampling_strategy(
#
# ~\AppData\Roaming\Python\Python36\site-packages\imblearn\base.py in _check_X_y(self, X, y, accept_sparse)
#     133         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
#     134         X, y = self._validate_data(
# --> 135             X, y, reset=True, accept_sparse=accept_sparse
# ...

# %%
df1=pd.get_dummies(bank_full.y,drop_first=False)
bank_full = pd.concat([bank_full,df1],axis=1).head()
bank_full.drop('y',axis=1,inplace=True)
bank_full.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome  no  yes
# 0  unknown    5   may       261         1     -1         0  unknown   1    0
# 1  unknown    5   may       151         1     -1         0  unknown   1    0
# 2  unknown    5   may        76         1     -1         0  unknown   1    0
# 3  unknown    5   may        92         1     -1         0  unknown   1    0
# 4  unknown    5   may       198         1     -1         0  unknown   1    0

# %%
x=bank_full.iloc()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-3d2e85211860> in <module>()
# ----> 1 sb.countplot(x="y",data=bank_full)
#
# C:\Users\Public\Miniconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3357                           estimator, ci, n_boot, units,
#    3358                           orient, color, palette, saturation,
# -> 3359                           errcolor, errwidth, capsize, dodge)
#    3360
#    3361     plotter.value_label = "count"
#
# C:\Users\Public\Miniconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1594         """Initialize the plotter."""
# ...
